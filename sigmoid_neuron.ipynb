# %% [markdown]
# <a href="https://colab.research.google.com/github/mohitsharma415/CPU-Scheduling/blob/master/sigmoid_neuron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Ploting Sigmoid

# %% [markdown]
# 1-d Sigmoid neuron

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def sigmoid(x,w,b):
  return 1/(1+np.exp(-w*x+b))

# %%
sigmoid(1,0.5,0)
# Out:
# 0.6224593312018546

# %%
w=-1.8
b=0.3
x=np.linspace(-10,10,20)

# %%
y=sigmoid(x,w,b)

# %%
type(y)
# Out:
# numpy.ndarray

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# **Here, in sigmoid neuron w is responsable for the rate of fall and b is responsable of the position of rate of fall with respect to origin.**

# %% [markdown]
# #2-Dimensional Sigmoid neuron

# %%
def twod_Sigmoid(x1,x2,w1,w2,b):
  return 1/(1+np.exp(-(w1*x1+w2*x2+b)))

# %%
x1=np.linspace(-10,10,50)
x2=np.linspace(-10,10,50)
w1=0.5
w2=2
b=0

# %%
from mpl_toolkits import mplot3d
# %matplotlib inline

# %%
X, Y = np.meshgrid(x1, x2)
Z = twod_Sigmoid(X,Y,w1,w2,b)

# %%
x.shape
# Out:
# (20,)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');

# %%
ax.view_init(30,180)
fig

# %% [markdown]
# #Compute Loss for a given dataset

# %%
w_unknown=0.5
b_unknown=0.5
X=np.random.random(25)*20-10
Y=sigmoid(X,w_unknown,b_unknown)
print(y)
# Out:
# [0.12455336 0.18159839 0.25709718 0.35053995 0.45705055 0.56763838
#  0.67187257 0.76153455 0.83279342 0.88594762]

# %%
plt.plot(X,Y,'*')
plt.show()

# %%
def calculated_loss(X,Y,w_est,b_est):
  loss=0
  for x,y in zip(X,Y):
    loss += (y-sigmoid(x,w_est,b_est))**2
  return loss

# %%
W=np.linspace(0,2,100)
B=np.linspace(-1,1,100)
WW,BB = np.meshgrid(W,B)
Loss= np.zeros(WW.shape)

# %%
for i in range(WW.shape[0]):
  for j in range(WW.shape[1]):
    Loss[i,j]=calculated_loss(X,Y,WW[i,j],BB[i,j])

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(WW, BB, Loss, cmap='viridis')
ax.set_xlabel('WW')
ax.set_ylabel('BB')
ax.set_zlabel('lOSS');

# %%
ax.view_init(30,270)
fig

# %%
ij=np.argmin(Loss)
i=np.floor(ij/Loss.shape[1])
j=ij-i*Loss.shape[1]
print(i,j)
# Out:
# 75.0 25.0

# %%
Loss[int(i),int(j)]
# Out:
# 8.305313783030153e-05

# %%
print(WW[int(i),int(j)]  , BB[int(i),int(j)])
# Out:
# 0.5050505050505051 0.5151515151515154
